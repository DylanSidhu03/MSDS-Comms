# %% [markdown]
# # simpleviz-dgsidhu — demo
#
# *PyPI:* https://pypi.org/project/simpleviz-dgsidhu/  ·  *Source:* https://github.com/DylanSidhu03/MSDS-Comms

# %% [markdown]
# ## 1 · Install, import, README

# %%
# !pip install simpleviz-dgsidhu

# %%
import simpleviz_dgsidhu as sv
print('version:', sv.__version__)
print('functions:', sv.__all__)

# %% [markdown]
# A quick look at the README, rendered inline (run from the cloned repo folder):

# %%
from IPython.display import Markdown, display
display(Markdown(open('README.md').read()))

# %% [markdown]
# ## 2 · Two favorite visualizations

# %%
import pandas as pd

regions = pd.DataFrame({
    'category': ['Alpha', 'Beta', 'Gamma', 'Delta'],
    'North': [420, 310, 260, 190],
    'South': [300, 330, 240, 210],
    'East':  [180, 220, 300, 160],
})

months = pd.DataFrame({
    'month': pd.date_range('2026-01-01', periods=12, freq='MS'),
    'revenue': [100,110,105,130,150,145,160,170,165,180,200,210],
})

# %% [markdown]
# ### Favorite #1 — grouped bar chart

# %%
ax = sv.bar(regions, 'category', ['North', 'South', 'East'],
            title='Sales by Region',
            subtitle='Earthy palette, rounded bars',
            ylabel='USD (thousands)')

# %% [markdown]
# ### Favorite #2 — line chart with area fill

# %%
ax = sv.line(months, 'revenue', x='month',
             title='Monthly Revenue',
             subtitle='Single series with area fill')
